# %%
import pandas as pd

# %%
pd.read_table('./annotations/california_wildfires_final_data.tsv', sep='\t')
# Out:
#                 tweet_id              image_id        text_info  \
# 0     917791044158185473  917791044158185473_0      informative
# 1     917791130590183424  917791130590183424_0      informative
# 2     917791291823591425  917791291823591425_0      informative
# 3     917791291823591425  917791291823591425_1      informative
# 4     917792092100988929  917792092100988929_0      informative
# ...                  ...                   ...              ...
# 1584  923761170967797761  923761170967797761_0      informative
# 1585  923796193670336512  923796193670336512_0      informative
# 1586  923821955568013313  923821955568013313_0  not_informative
# 1587  923844053426348032  923844053426348032_0      informative
# 1588  923879231175630848  923879231175630848_0  not_informative
#
#       text_info_conf       image_info  image_info_conf  \
# 0             1.0000      informative           0.6766
# 1             1.0000      informative           0.6667
# ...

# %%
import pandas as pd
import glob


all_files = glob.glob("./annotations/*.tsv")

li = []

for filename in all_files:

    df = pd.read_table(filename, index_col=None, header=0, sep='\t')
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
# Out:
# ./annotations/california_wildfires_final_data.tsv
# ./annotations/srilanka_floods_final_data.tsv
# ./annotations/hurricane_harvey_final_data.tsv
# ./annotations/hurricane_maria_final_data.tsv
# ./annotations/iraq_iran_earthquake_final_data.tsv
# ./annotations/hurricane_irma_final_data.tsv
# ./annotations/mexico_earthquake_final_data.tsv

# %%
frame
# Out:
#                  tweet_id              image_id    text_info  text_info_conf  \
# 0      917791044158185473  917791044158185473_0  informative          1.0000
# 1      917791130590183424  917791130590183424_0  informative          1.0000
# 2      917791291823591425  917791291823591425_0  informative          0.6813
# 3      917791291823591425  917791291823591425_1  informative          0.6813
# 4      917792092100988929  917792092100988929_0  informative          0.6727
# ...                   ...                   ...          ...             ...
# 18077  916105333872918528  916105333872918528_0  informative          1.0000
# 18078  916105374134042624  916105374134042624_0  informative          1.0000
# 18079  916112796194021376  916112796194021376_0  informative          1.0000
# 18080  916164076484653056  916164076484653056_0  informative          0.6580
# 18081  916167674673156096  916167674673156096_0  informative          0.5635
#
#             image_info  image_info_conf  \
# ...

# %%
frame.columns
# Out:
# Index(['tweet_id', 'image_id', 'text_info', 'text_info_conf', 'image_info',
#        'image_info_conf', 'text_human', 'text_human_conf', 'image_human',
#        'image_human_conf', 'image_damage', 'image_damage_conf', 'tweet_text',
#        'image_url', 'image_path'],
#       dtype='object')

# %%
frame[frame['tweet_id']==909914772816179201]
# Out:
#                  tweet_id              image_id    text_info  text_info_conf  \
# 15185  909914772816179201  909914772816179201_0  informative             1.0
# 15186  909914772816179201  909914772816179201_1  informative             1.0
# 15187  909914772816179201  909914772816179201_2  informative             1.0
# 15188  909914772816179201  909914772816179201_3  informative             1.0
#
#             image_info  image_info_conf                  text_human  \
# 15185      informative           1.0000  other_relevant_information
# 15186  not_informative           0.3529  other_relevant_information
# 15187  not_informative           0.6587  other_relevant_information
# 15188      informative           0.6573  other_relevant_information
#
#        text_human_conf                        image_human  image_human_conf  \
# 15185              1.0  infrastructure_and_utility_damage            1.0000
# 15186              1.0                   not_humanitarian            0.3529
# ...

# %%
frame = frame.drop_duplicates(subset='tweet_id', keep="first")

# %%
len(frame)
# Out:
# 16058

# %%
frame.drop(frame.columns.difference(['text_info','tweet_text']), 1, inplace=True)

# %%
frame.columns=["Informativeness","text"]

# %%
frame['Informativeness']=frame['Informativeness'].map(lambda x: 1 if(x=='informative') else 0)

# %%
frame["Informativeness"].value_counts()
# Out:
# 1    11503
# 0     4555
# Name: Informativeness, dtype: int64

# %%
frame.to_pickle("./new_data.pkl")

# %%
frame_only_unimformative=frame[frame["Informativeness"]==0].reset_index()

# %%
frame_only_unimformative.to_pickle("./new_data_unimformative.pkl")
