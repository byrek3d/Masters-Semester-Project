# %%
import pandas as pd
from langdetect import detect
import tweepy

# %%
main_df=pd.read_table("./dataset3.tsv")

# %%
main_df.head()
# Out:
#                     id  label
# 0  1006567084833329152      0
# 1   948268958054080512      1
# 2           1386191114      0
# 3   942069796765683713      0
# 4   942151866380582912      0

# %%
# Authenticate to Twitter
auth = tweepy.OAuthHandler("ZbcylrnqHEgkBqwKaiTYgYNL0",
    "EpBfljAfXaG4V9isnXLRQWk1fAL8pZ5iZnyKX4yfUxHmeFuErQ")
auth.set_access_token("1276163142087827460-mYhybK15AhqqKOzTUM4xBGMT8mNOqN",
    "vku1KbNkhQmSVUQPrVj6ReMhnLTsJlsNuJRwyg6DgZAFH")

api = tweepy.API(auth,wait_on_rate_limit=True,
    wait_on_rate_limit_notify=True)

try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during authentication")
# Out:
# Authentication OK

# %%
def get_tweet_text(tweet_id):
    try:
        tweet = api.get_status(id=tweet_id)
    except Exception as e:
        print(e)
        print("Error with tweet:{} ".format(tweet_id))
        return ""
    return tweet

# %%
main_df['APIdata'] = main_df.apply (lambda row: get_tweet_text(row.id), axis=1)
# Out:
# [{'code': 179, 'message': 'Sorry, you are not authorized to see this status.'}]
# Error with tweet:903584488944521216
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error with tweet:903580752671117312
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error with tweet:1006567127896219654
# [{'code': 63, 'message': 'User has been suspended.'}]
# Error with tweet:494025569101553665
# [{'code': 63, 'message': 'User has been suspended.'}]
# Error with tweet:1070941320758378496
# [{'code': 63, 'message': 'User has been suspended.'}]
# Error with tweet:1070716229839699975
# [{'code': 144, 'message': 'No status found with that ID.'}]
# Error with tweet:850355121301147648
# [{'code': 63, 'message': 'User has been suspended.'}]
# Error with tweet:494022904183803904
# [{'code': 63, 'message': 'User has been suspended.'}]
# Error with tweet:959804243065503749
# [{'code': 63, 'message': 'User has been suspended.'}]
# Error with tweet:1069830790492483586
# ...

# %%
main_df.to_pickle("./dataset3AllAPIData.pkl")

# %%
main_df= main_df[main_df["APIdata"]!=""]

# %%
main_df.iloc[0].APIdata.text
# Out:
# 'Off we go #NintendoE3 https://t.co/WtBVsQlDcK'

# %%
main_df['text'] = main_df.apply (lambda row: row["APIdata"].text, axis=1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
main_df.head()
# Out:
#                     id  label  \
# 0  1006567084833329152      0
# 1   948268958054080512      1
# 2           1386191114      0
# 3   942069796765683713      0
# 4   942151866380582912      0
#
#                                              APIdata  \
# 0  Status(_api=<tweepy.api.API object at 0x11d16f...
# 1  Status(_api=<tweepy.api.API object at 0x11d16f...
# 2  Status(_api=<tweepy.api.API object at 0x11d16f...
# 3  Status(_api=<tweepy.api.API object at 0x11d16f...
# 4  Status(_api=<tweepy.api.API object at 0x11d16f...
#
#                                                 text
# 0      Off we go #NintendoE3 https://t.co/WtBVsQlDcK
# 1  Maryland high school student Liza Goldberg has...
# 2  Doing some research into 'the internet of thin...
# 3  Thank you everyone for the amazing #AGU17! Poe...
# 4  #agu17 - where you think the meeting is over a...

# %%
main_df= main_df[["label","text"]]

# %%
main_df.columns=["Informativeness","text"]

# %%
pd.set_option('display.max_colwidth', -1)
main_df.text= main_df.apply(lambda x: x.text.replace("\n"," "), axis=1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
main_df
# Out:
#       Informativeness  \
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
# ...  ..
# 2986  0
# 2987  1
# 2989  0
# 2990  0
# 2991  1
#
#                                                                                                                                                   text
# 0     Off we go #NintendoE3 https://t.co/WtBVsQlDcK
# 1     Maryland high school student Liza Goldberg has developed what might be the world’s first satellite-based early warn… https://t.co/khxHEWmIQA
# 2     Doing some research into 'the internet of things'...
# 3     Thank you everyone for the amazing #AGU17! Poetry, polaroids, po-boys, posters, and fantastic people. Looking forwa… https://t.co/GqJ5GSrnm9
# 4     #agu17 - where you think the meeting is over and accidentally meet long-admired scientists at the airport bar. Than… https://t.co/pFvajEOPVq
# ...

# %%
### Keep only english tweets

def is_english(text):

    try:
          language = detect(text)
    except:
          #These will be removed
          print("This row throws and error:", text)
          return False;
    if(language=='en'):
      return True;
    else:
      return False;

main_df=main_df[main_df.apply(lambda x: is_english(x['text']), axis=1)]

# %%
len(main_df)
# Out:
# 2517

# %%
main_df.to_pickle("./../dataset3Cleaned.pkl")
