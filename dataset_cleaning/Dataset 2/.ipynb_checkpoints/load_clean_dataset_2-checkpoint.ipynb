# %%
import pandas as pd
from langdetect import detect
import glob

# %%
all_files = glob.glob("./annotations/*.tsv")

li = []

for filename in all_files:

    df = pd.read_table(filename, index_col=None, header=0, sep='\t')
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#                  tweet_id              image_id    text_info  text_info_conf  \
# 0      917791044158185473  917791044158185473_0  informative          1.0000
# 1      917791130590183424  917791130590183424_0  informative          1.0000
# 2      917791291823591425  917791291823591425_0  informative          0.6813
# 3      917791291823591425  917791291823591425_1  informative          0.6813
# 4      917792092100988929  917792092100988929_0  informative          0.6727
# ...                   ...                   ...          ...             ...
# 18077  916105333872918528  916105333872918528_0  informative          1.0000
# 18078  916105374134042624  916105374134042624_0  informative          1.0000
# 18079  916112796194021376  916112796194021376_0  informative          1.0000
# 18080  916164076484653056  916164076484653056_0  informative          0.6580
# 18081  916167674673156096  916167674673156096_0  informative          0.5635
#
#             image_info  image_info_conf  \
# 0          informative           0.6766
# 1          informative           0.6667
# 2          informative           1.0000
# 3      not_informative           1.0000
# 4          informative           0.6612
# ...                ...              ...
# 18077  not_informative           1.0000
# 18078  not_informative           0.6412
# 18079      informative           0.6337
# 18080      informative           0.6374
# 18081  not_informative           1.0000
#
#                                    text_human  text_human_conf  \
# 0                  other_relevant_information           1.0000
# 1           infrastructure_and_utility_damage           1.0000
# 2                  other_relevant_information           0.6813
# 3                  other_relevant_information           0.6813
# 4                  other_relevant_information           0.6727
# ...                                       ...              ...
# 18077  rescue_volunteering_or_donation_effort           1.0000
# 18078  rescue_volunteering_or_donation_effort           1.0000
# 18079  rescue_volunteering_or_donation_effort           1.0000
# 18080              other_relevant_information           0.6580
# 18081                  injured_or_dead_people           0.5635
#
#                                   image_human  image_human_conf  \
# 0                  other_relevant_information            0.6766
# 1                        affected_individuals            0.6667
# 2           infrastructure_and_utility_damage            1.0000
# 3                            not_humanitarian            1.0000
# 4           infrastructure_and_utility_damage            0.6612
# ...                                       ...               ...
# 18077                        not_humanitarian            1.0000
# 18078                        not_humanitarian            0.6412
# 18079              other_relevant_information            0.6337
# 18080  rescue_volunteering_or_donation_effort            0.6374
# 18081                        not_humanitarian            1.0000
#
#         image_damage  image_damage_conf  \
# 0                NaN                NaN
# 1                NaN                NaN
# 2      severe_damage                1.0
# 3                NaN                NaN
# 4      severe_damage                1.0
# ...              ...                ...
# 18077            NaN                NaN
# 18078            NaN                NaN
# 18079            NaN                NaN
# 18080            NaN                NaN
# 18081            NaN                NaN
#
#                                               tweet_text  \
# 0      RT @Gizmodo: Wildfires raging through Northern...
# 1      PHOTOS: Deadly wildfires rage in California ht...
# 2      RT @Cal_OES: PLS SHARE: Weâ€™re capturing wild...
# 3      RT @Cal_OES: PLS SHARE: Weâ€™re capturing wild...
# 4      RT @TIME: California's raging wildfires as you...
# ...                                                  ...
# 18077  Carlos santana donates $100k to mexico earthqu...
# 18078  Seth troxler donates 10k to earthquake relief ...
# 18079  Entercom/San Francisco Stations Raise Funds Fo...
# 18080  Mexico Earthquakes | International Medical Cor...
# 18081  Napa school employee Valentin Fuentes Villanue...
#
#                                             image_url  \
# 0      http://pbs.twimg.com/media/DLyi_WYVYAApwNg.jpg
# 1      http://pbs.twimg.com/media/DLymKm9UMAAu0qw.jpg
# 2      http://pbs.twimg.com/media/DLudaaZV4AAjT7x.jpg
# 3      http://pbs.twimg.com/media/DLudaZXUMAABAEZ.jpg
# 4      http://pbs.twimg.com/media/DLwNe-NXUAE0XCw.jpg
# ...                                               ...
# 18077  http://pbs.twimg.com/media/DLao8g8W4AAKoPV.jpg
# 18078  http://pbs.twimg.com/media/DLao-2GWsAA97vC.jpg
# 18079  http://pbs.twimg.com/media/DLavu1YV4AAgSJ_.jpg
# 18080  http://pbs.twimg.com/media/DLbeXxlWsAEl9xu.jpg
# 18081  http://pbs.twimg.com/media/DLbhpNXW4AAGqC1.jpg
#
#                                               image_path
# 0      data_image/california_wildfires/10_10_2017/917...
# 1      data_image/california_wildfires/10_10_2017/917...
# 2      data_image/california_wildfires/10_10_2017/917...
# 3      data_image/california_wildfires/10_10_2017/917...
# 4      data_image/california_wildfires/10_10_2017/917...
# ...                                                  ...
# 18077  data_image/mexico_earthquake/6_10_2017/9161053...
# 18078  data_image/mexico_earthquake/6_10_2017/9161053...
# 18079  data_image/mexico_earthquake/6_10_2017/9161127...
# 18080  data_image/mexico_earthquake/6_10_2017/9161640...
# 18081  data_image/mexico_earthquake/6_10_2017/9161676...
#
# [18082 rows x 15 columns]

# %%
frame.columns
# Out:
# Index(['tweet_id', 'image_id', 'text_info', 'text_info_conf', 'image_info',
#        'image_info_conf', 'text_human', 'text_human_conf', 'image_human',
#        'image_human_conf', 'image_damage', 'image_damage_conf', 'tweet_text',
#        'image_url', 'image_path'],
#       dtype='object')

# %%
frame = frame.drop_duplicates(subset='tweet_id', keep="first")

# %%
len(frame)
# Out:
# 16058

# %%
frame.drop(frame.columns.difference(['tweet_id','text_info','tweet_text']), 1, inplace=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
frame.columns=["id","Informativeness","text"]

# %%
frame.Informativeness.value_counts()
# Out:
# informative        11503
# not_informative     4555
# Name: Informativeness, dtype: int64

# %%
### Keep only english tweets

def is_english(text):

    try:
          language = detect(text)
    except:
          #These will be removed
          print("This row throws and error:", text)
          return False;
    if(language=='en'):
      return True;
    else:
      return False;

frame_en=frame[frame.apply(lambda x: is_english(x['text']), axis=1)]

# %%
len(frame_en)
# Out:
# 15745

# %%
frame_en.Informativeness.value_counts()
# Out:
# informative        11365
# not_informative     4380
# Name: Informativeness, dtype: int64

# %%
frame_en.head()
# Out:
#                    id Informativeness  \
# 0  917791044158185473     informative
# 1  917791130590183424     informative
# 2  917791291823591425     informative
# 4  917792092100988929     informative
# 5  917792147700465664     informative
#
#                                                 text
# 0  RT @Gizmodo: Wildfires raging through Northern...
# 1  PHOTOS: Deadly wildfires rage in California ht...
# 2  RT @Cal_OES: PLS SHARE: Weâ€™re capturing wild...
# 4  RT @TIME: California's raging wildfires as you...
# 5  Wildfires Threaten Californiaâ€™s First Legal ...

# %%
frame_en['Informativeness']=frame_en['Informativeness'].map(lambda x: 1 if(x=='informative') else 0)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
frame_en["Informativeness"].value_counts()
# Out:
# 1    11365
# 0     4380
# Name: Informativeness, dtype: int64

# %%
frame_en.to_pickle("./../dataset2Cleaned.pkl")

# %%
users=pd.read_csv('./../tj/parsed/twitter_user.csv')

# %%
authors=pd.read_csv('./../tj/parsed/tweet_metadata.csv')

# %%
merged=pd.merge(frame_en, authors, on='id')

# %%
merged.drop(merged.columns.difference(['id', 'Informativeness', 'text', 'author_id', 'tweet_type', 'retweet_count', 'favorite_count']), 1, inplace=True)

# %%
merged.head()
# Out:
#                    id  Informativeness  \
# 0  917791130590183424                1
# 1  917791291823591425                1
# 2  917792092100988929                1
# 3  917792147700465664                1
# 4  917793158251077632                1
#
#                                                 text           author_id  \
# 0  PHOTOS: Deadly wildfires rage in California ht...            23085284
# 1  RT @Cal_OES: PLS SHARE: Weâ€™re capturing wild...  765553757887266816
# 2  RT @TIME: California's raging wildfires as you...          1143801686
# 3  Wildfires Threaten Californiaâ€™s First Legal ...  743291168092364805
# 4  RT @FoxNews: Southern California fire shrouds ...            69611563
#
#   tweet_type  retweet_count  favorite_count
# 0      tweet              0               0
# 1    retweet            497               0
# 2    retweet            197               0
# 3      tweet              0               0
# 4    retweet             66               0

# %%
users.head()
# Out:
#    author_id                                    has_description  \
# 0    6925932                             娘魔の3歳です。仲良くやってます・・・(笑)
# 1     820569  Author of THIS TIME THE FIRE and UNINVENTABLES...
# 2    4926751  Life's how you develop it.|Papa van 💁‍♀️💁‍♂️🙅‍...
# 3    6013032                                                NaN
# 4    5916622  なー！起きるのと片付けが苦手。惰眠に惨敗な人生、そんな自分に甘えまくり好きな事ばかりしてる。...
#
#                bio_has_url  followers_count  friends_count  favourites_count  \
# 0                      NaN               84            555             42060
# 1   http://t.co/mpmrJeB7hX              682           1487              4989
# 2  https://t.co/uas8e6LpeN             1181            956              2750
# 3                      NaN                0              0                 0
# 4   http://t.co/ntGHFHbqPF              119            203               586
#
#    listed_count  statuses_count  protected  verified  default_profile  \
# 0           0.0            2893      False     False            False
# 1          29.0            9394      False     False            False
# 2          37.0           41861      False     False            False
# 3           0.0           23774      False     False            False
# 4           7.0            8767      False     False            False
#
#    default_profile_image
# 0                  False
# 1                  False
# 2                  False
# 3                   True
# 4                  False

# %%
users.columns
# Out:
# Index(['id', 'description', 'url', 'followers_count', 'friends_count',
#        'favourites_count', 'listed_count', 'statuses_count', 'protected',
#        'verified', 'default_profile', 'default_profile_image'],
#       dtype='object')

# %%
users.drop(columns=['created_at', 'lang', 'name', 'screen_name', 'location','access'], inplace=True)

# %%
users.columns=['author_id', 'has_description', 'bio_has_url', 'followers_count', 'friends_count',
       'favourites_count', 'listed_count', 'statuses_count', 'protected',
       'verified', 'default_profile', 'default_profile_image']

# %%
merged=pd.merge(merged, users, on='author_id')

# %%
pd.read_csv('./../tj/parsed/view_user_stats.csv')
# Out:
#          author_id  tw_num  do_rt_num  get_rt_num
# 0       1000002343       1          0           0
# 1       1000018914       1          1           0
# 2       1000023236       1          0           0
# 3       1000032338       1          1           0
# 4        100003468       1          1           0
# ...            ...     ...        ...         ...
# 241959   999982998       1          0           0
# 241960    99998316       1          0           0
# 241961   999985153       1          1           0
# 241962    99999199       1          1           0
# 241963    99999566       1          0           1
#
# [241964 rows x 4 columns]

# %%
merged
# Out:
#                        id  Informativeness  \
# 0      917791130590183424                1
# 1      914624000625541121                1
# 2      917791291823591425                1
# 3      917792092100988929                1
# 4      917792147700465664                1
# ...                   ...              ...
# 12412  915972133746040833                1
# 12413  915972197319155712                0
# 12414  916075589131436032                1
# 12415  916164076484653056                1
# 12416  916167674673156096                1
#
#                                                     text           author_id  \
# 0      PHOTOS: Deadly wildfires rage in California ht...            23085284
# 1      Family helps community by cooking meals for do...            23085284
# 2      RT @Cal_OES: PLS SHARE: Weâ€™re capturing wild...  765553757887266816
# 3      RT @TIME: California's raging wildfires as you...          1143801686
# 4      Wildfires Threaten Californiaâ€™s First Legal ...  743291168092364805
# ...                                                  ...                 ...
# 12412  Mexico City's Earthquake Alert Worked. The Res...  852588989659963393
# 12413  Photos that will make you want to Visit Mexico...             6660222
# 12414  A Wave Of Natural Disasters StrikeÂ Mexico htt...  862739444419493889
# 12415  Mexico Earthquakes | International Medical Cor...            10118982
# 12416  Napa school employee Valentin Fuentes Villanue...            20558644
#
#       tweet_type  retweet_count  favorite_count  \
# 0          tweet              0               0
# 1          tweet              0               0
# 2        retweet            497               0
# 3        retweet            197               0
# 4          tweet              0               0
# ...          ...            ...             ...
# 12412      tweet              1               1
# 12413      tweet              0               0
# 12414      tweet              0               0
# 12415      tweet              0               0
# 12416      tweet              4              13
#
#                                          has_description  \
# 0      Real-time updates from WMTW News 8: Maine's To...
# 1      Real-time updates from WMTW News 8: Maine's To...
# 2      Official Twitter account of Alerts Made Easy®....
# 3      Anarchist furry trans pan degenerate that play...
# 4      Getting out the latest information in the Cann...
# ...                                                  ...
# 12412  My name is Justin Habana. Self proclaimed Huma...
# 12413  Video Consultant: https://t.co/hfQDKOjjWC OG t...
# 12414  Dedicated to delivering the most premium, non-...
# 12415  Single, 53, no children. Let's talk about it o...
# 12416  Breaking news, politics, features, photos, sta...
#
#                    bio_has_url  followers_count  friends_count  \
# 0      https://t.co/hJRuLYj5zC            87310            417
# 1      https://t.co/hJRuLYj5zC            87310            417
# 2      https://t.co/NTpDIXXuLv               63            217
# 3                          NaN               71            146
# 4                          NaN            11350            366
# ...                        ...              ...            ...
# 12412                      NaN              710            492
# 12413  https://t.co/6Hts4agQXc             6280           3128
# 12414  https://t.co/Yk6kTj1A6T              203           3049
# 12415  https://t.co/WXpZYqAQbU             2978           4998
# 12416   http://t.co/W9yS64EPVg            34025            295
#
#        favourites_count  listed_count  statuses_count  protected  verified  \
# 0                   213         692.0          270112      False      True
# 1                   213         692.0          270112      False      True
# 2                  2994           4.0            3864      False     False
# 3                 15903           1.0            6560      False     False
# 4                   180          87.0           76350      False     False
# ...                 ...           ...             ...        ...       ...
# 12412                11           2.0            1066      False     False
# 12413              7670         488.0           36269      False     False
# 12414               188           4.0             243      False     False
# 12415            228939         435.0          426955      False     False
# 12416               189         626.0           51132      False      True
#
#        default_profile  default_profile_image
# 0                False                  False
# 1                False                  False
# 2                 True                  False
# 3                False                  False
# 4                False                  False
# ...                ...                    ...
# 12412             True                  False
# 12413            False                  False
# 12414             True                  False
# 12415            False                  False
# 12416            False                  False
#
# [12417 rows x 18 columns]
